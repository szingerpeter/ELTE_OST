# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %%
df = pd.read_csv('data/data.txt', sep = '\s+')

# %%
df.head()
# Out:
#          date   max  min
# 0  01-01-2008   6.0 -0.2
# 1  02-01-2008   7.0  3.7
# 2  03-01-2008   7.8  4.4
# 3  04-01-2008   8.6  3.5
# 4  05-01-2008  10.6  4.9

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date   max  min
# 0 2008-01-01   6.0 -0.2
# 1 2008-02-01   7.0  3.7
# 2 2008-03-01   7.8  4.4
# 3 2008-04-01   8.6  3.5
# 4 2008-05-01  10.6  4.9

# %%
df = df.sort_values('date', ascending=True)
plt.plot(df['date'], df['max'])
plt.xticks(rotation='vertical')
# Out:
# (array([732312., 733042., 733773., 734503., 735234., 735964., 736695.,
#         737425., 738156.]), <a list of 9 Text xticklabel objects>)

# %%
plt.style.use("seaborn-dark-palette") 

fig,ax = plt.subplots()

df_plot = df.loc[(df['date'] > datetime.datetime(2019, 1, 1)) & (df['date'] < datetime.datetime(2020, 1, 1))]

ax.plot(df_plot['date'], df_plot['max'], label='max')
ax.plot(df_plot['date'], df_plot['min'], label='min')

plt.title("Min/Max temperature along the year 2019 in Madrid")

plt.show()

# %%
plt.style.use("seaborn-dark-palette")

# Histogram
heights,bins = np.histogram(df_plot['max'],bins=50)

plt.plot(bins[:-1],heights)

plt.title("Maximum temperature distribution")

plt.show()

# Histogram
heights,bins = np.histogram(df_plot['min'],bins=50)

plt.plot(bins[:-1],heights)

plt.title("Minimum temperature distribution")

plt.show()

# %%
df['date'] = df.apply(lambda x: x['date'].strftime('%Y-%m-%d'),axis=1)

# %%
df['date'] = df['date'].astype('str')

# %%
df['location_id'] = 1

# %%
df.to_csv('data/data.csv', sep=',', index=False)
